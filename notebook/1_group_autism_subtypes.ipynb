# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Load data

# %%
# load DisGenet curated raw data
df = pd.read_csv("../raw_data/curated_gene_disease_associations.tsv", sep='\t')
df.head(1)
# Out:
#    geneId geneSymbol    DSI    DPI diseaseId   diseaseName diseaseType  \
# 0       1       A1BG  0.857  0.172  C0019209  Hepatomegaly   phenotype
#
#   diseaseClass diseaseSemanticType  score  EI  YearInitial  YearFinal  \
# 0      C06;C23             Finding    0.3 NaN       2017.0     2017.0
#
#    NofPmids  NofSnps     source
# 0         1        0  CTD_human

# %%
# Create diseases 
diseases = df[['diseaseId', 'diseaseName', 'diseaseType', 'diseaseClass', 'diseaseSemanticType']].drop_duplicates()
diseases.head()
# Out:
#   diseaseId               diseaseName diseaseType diseaseClass  \
# 0  C0019209              Hepatomegaly   phenotype      C06;C23
# 1  C0036341             Schizophrenia     disease          F03
# 2  C0002395       Alzheimer's Disease     disease      C10;F03
# 3  C0007102  Malignant tumor of colon     disease      C04;C06
# 4  C0009375         Colonic Neoplasms       group      C04;C06
#
#                 diseaseSemanticType
# 0                           Finding
# 1  Mental or Behavioral Dysfunction
# 2               Disease or Syndrome
# 3                Neoplastic Process
# 4                Neoplastic Process

# %%
# load autism terms
autisms = pd.read_csv('processed_data/autism_terms.csv', sep='\t').iloc[:,1:]
autisms.head()
# Out:
#   diseaseId                                       diseaseName  \
# 0  C0004352                                 Autistic Disorder
# 1  C1510586                         Autism Spectrum Disorders
# 2  C3275438             AUTISM, SUSCEPTIBILITY TO, X-LINKED 5
# 3  C3552491                    AUTISM, SUSCEPTIBILITY TO, 14A
# 4  C1845540  AUTISM, X-LINKED, SUSCEPTIBILITY TO, 1 (finding)
#
#              autism_subtype  autism_subtype_broad
# 0  Autism Spectrum Disorder  Non-Syndromic Autism
# 1  Autism Spectrum Disorder  Non-Syndromic Autism
# 2  Autism Spectrum Disorder  Non-Syndromic Autism
# 3  Autism Spectrum Disorder  Non-Syndromic Autism
# 4  Autism Spectrum Disorder  Non-Syndromic Autism

# %%
autisms['diseaseId'] = autisms['diseaseId'].astype(str)
diseases['diseaseId'] = diseases['diseaseId'].astype(str)

# %%
autisms_df = autisms.merge(
    diseases[['diseaseId', 'diseaseType', 'diseaseClass', 'diseaseSemanticType']],
    on="diseaseId",
    how='left')

autisms_df.tail()
# Out:
#    diseaseId                                   diseaseName  \
# 67  C0175702                             Williams Syndrome
# 68  C0012236                             DiGeorge Syndrome
# 69  C2936346                       22q11 Deletion Syndrome
# 70  C2678480  Chromosome 22q11.2 Deletion Syndrome, Distal
# 71  C1854416                  MACROCEPHALY/AUTISM SYNDROME
#
#                    autism_subtype autism_subtype_broad diseaseType  \
# 67               William Syndrome     Syndromic Autism     disease
# 68              Digeorge Syndrome     Syndromic Autism     disease
# 69              Digeorge Syndrome     Syndromic Autism     disease
# 70              Digeorge Syndrome     Syndromic Autism     disease
# 71  Macrocephaly/Autism Syndrome      Syndromic Autism     disease
#
#                diseaseClass  diseaseSemanticType
# 67              C10;C14;C16  Disease or Syndrome
# 68      C05;C14;C15;C16;C19  Disease or Syndrome
# 69      C05;C14;C15;C16;C19  Disease or Syndrome
# 70  C05;C14;C15;C16;C19;C23  Disease or Syndrome
# 71      C05;C10;C16;C23;F03  Disease or Syndrome

# %% [markdown]
# ## Create col: disease ids, name, autism_subtype

# %%
autism_types_names = pd.Series(autisms_df['autism_subtype'].unique())

autism_types_new_id = "A" + pd.Series([str(i).zfill(2) for i in range(0, len(autism_types_names))])
autism_new_ids = pd.concat([autism_types_names, autism_types_new_id], axis=1)
autism_new_ids = autism_new_ids.rename(columns={0: 'diseaseName', 1:"diseaseId"})
autism_new_ids
# Out:
#                       diseaseName diseaseId
# 0        Autism Spectrum Disorder       A00
# 1                   Rett Syndrome       A01
# 2              Fragile X Syndrome       A02
# 3      MECP2 duplication Syndrome       A03
# 4      Tuberous Sclerosis Complex       A04
# 5               Angelman Syndrome       A05
# 6                Timothy Syndrome       A06
# 7      Smith-Lemli-Opitz Syndrome       A07
# 8               Neurofibromatosis       A08
# 9        Hamartoma tumor Syndrome       A09
# 10                  Down Syndrome       A10
# 11                 Cohen Syndrome       A11
# 12     Cornelia de Lange Syndrome       A12
# 13                Charge Syndrome       A13
# 14                Noonan Syndrome       A14
# 15               William Syndrome       A15
# 16              Digeorge Syndrome       A16
# 17  Macrocephaly/Autism Syndrome        A17

# %%
# Create new columns
autism_new_ids.loc[0, 'autism_subtype_broad'] = 'Non-Syndromic Autism'
autism_new_ids.loc[1:, 'autism_subtype_broad'] = 'Syndromic Autism'
autism_new_ids.head(2)
# Out:
#                 diseaseName diseaseId  autism_subtype_broad
# 0  Autism Spectrum Disorder       A00  Non-Syndromic Autism
# 1             Rett Syndrome       A01      Syndromic Autism

# %% [markdown]
# ## Create col: disease type

# %%
autisms_df[['autism_subtype', 'diseaseType']].drop_duplicates()
# Out:
#                    autism_subtype diseaseType
# 0        Autism Spectrum Disorder       group
# 1        Autism Spectrum Disorder     disease
# 2        Autism Spectrum Disorder   phenotype
# 12                  Rett Syndrome     disease
# 17             Fragile X Syndrome     disease
# 19     MECP2 duplication Syndrome     disease
# 20     Tuberous Sclerosis Complex     disease
# 25              Angelman Syndrome     disease
# 26               Timothy Syndrome     disease
# 27     Smith-Lemli-Opitz Syndrome     disease
# 30              Neurofibromatosis     disease
# 36       Hamartoma tumor Syndrome     disease
# 38                  Down Syndrome     disease
# 43                 Cohen Syndrome     disease
# 45     Cornelia de Lange Syndrome     disease
# 49                Charge Syndrome     disease
# 51                Noonan Syndrome     disease
# 67               William Syndrome     disease
# 68              Digeorge Syndrome     disease
# 71  Macrocephaly/Autism Syndrome      disease

# %%
autism_new_ids['diseaseType'] = 'disease'
autism_new_ids.head(2)
# Out:
#                 diseaseName diseaseId  autism_subtype_broad diseaseType
# 0  Autism Spectrum Disorder       A00  Non-Syndromic Autism     disease
# 1             Rett Syndrome       A01      Syndromic Autism     disease

# %% [markdown]
# ## Create col: diseaseClass

# %%
autism_classes = autisms_df[['autism_subtype', 'diseaseClass']].drop_duplicates()
autism_classes.head()
# Out:
#               autism_subtype diseaseClass
# 0   Autism Spectrum Disorder          F03
# 2   Autism Spectrum Disorder          NaN
# 12             Rett Syndrome      C10;C16
# 16             Rett Syndrome          NaN
# 17        Fragile X Syndrome      C10;C16

# %%
for i, row in autism_new_ids.iterrows(): 
    df_temp = autism_classes[autism_classes['autism_subtype']==row['diseaseName']]
    list_temp = []
    for _, row_2 in df_temp.iterrows():
        if row_2['diseaseClass'] is not np.nan:
            classes = row_2['diseaseClass']
            if ";" in classes:
                list_temp += (classes.split(';'))
            else:
                list_temp.append(classes)
    list_temp = sorted(list(set(list_temp)))
    print(list_temp)
    autism_new_ids.loc[i, 'diseaseClass'] = ";".join(list_temp)
# Out:
# ['F03']
# ['C10', 'C16']
# ['C10', 'C16', 'C23']
# ['C10', 'C16']
# ['C04', 'C10', 'C12', 'C13', 'C16']
# ['C10', 'C16']
# ['C05', 'C14', 'C16', 'C23', 'F03']
# ['C16', 'C18']
# ['C04', 'C09', 'C10', 'C16', 'C17', 'C23']
# ['C04', 'C16']
# ['C04', 'C09', 'C10', 'C11', 'C15', 'C16', 'C23', 'F01', 'F03']
# ['C05', 'C10', 'C11', 'C16', 'C18', 'C23', 'F01', 'F03']
# ['C10', 'C16']
# ['C16']
# ['C04', 'C05', 'C10', 'C14', 'C16', 'C17', 'C23']
# ['C10', 'C14', 'C16']
# ['C05', 'C14', 'C15', 'C16', 'C19', 'C23']
# ['C05', 'C10', 'C16', 'C23', 'F03']

# %% [markdown]
# ### Create col: 'diseaseSemanticType'

# %%
autism_semantictypes = autisms_df[['autism_subtype', 'diseaseSemanticType']].drop_duplicates()
autism_semantictypes = autism_semantictypes.reset_index().iloc[:, 1:]
autism_semantictypes
# Out:
#                    autism_subtype               diseaseSemanticType
# 0        Autism Spectrum Disorder  Mental or Behavioral Dysfunction
# 1        Autism Spectrum Disorder                           Finding
# 2        Autism Spectrum Disorder               Disease or Syndrome
# 3                   Rett Syndrome               Disease or Syndrome
# 4              Fragile X Syndrome               Disease or Syndrome
# 5      MECP2 duplication Syndrome               Disease or Syndrome
# 6      Tuberous Sclerosis Complex                Neoplastic Process
# 7      Tuberous Sclerosis Complex               Disease or Syndrome
# 8               Angelman Syndrome               Disease or Syndrome
# 9                Timothy Syndrome               Disease or Syndrome
# 10     Smith-Lemli-Opitz Syndrome               Disease or Syndrome
# 11              Neurofibromatosis                Neoplastic Process
# 12              Neurofibromatosis               Disease or Syndrome
# 13       Hamartoma tumor Syndrome                Neoplastic Process
# 14                  Down Syndrome               Disease or Syndrome
# 15                  Down Syndrome                Neoplastic Process
# 16                 Cohen Syndrome               Disease or Syndrome
# 17                 Cohen Syndrome            Congenital Abnormality
# 18     Cornelia de Lange Syndrome               Disease or Syndrome
# 19                Charge Syndrome               Disease or Syndrome
# 20                Noonan Syndrome               Disease or Syndrome
# 21               William Syndrome               Disease or Syndrome
# 22              Digeorge Syndrome               Disease or Syndrome
# 23  Macrocephaly/Autism Syndrome                Disease or Syndrome

# %%
def relabel(autism_type, semantic_type):
    autism_semantictypes.loc[autism_semantictypes['autism_subtype']==autism_type, 'diseaseSemanticType'] = semantic_type

# %%
relabel('Autism Spectrum Disorder', 'Mental or Behavioral Dysfunction')
relabel('Tuberous Sclerosis Complex', 'Disease or Syndrome')
relabel('Neurofibromatosis', 'Disease or Syndrome')
relabel('Down Syndrome', 'Disease or Syndrome')
relabel('Cohen Syndrome', 'Congenital Abnormality')

# %%
autism_semantictypes = autism_semantictypes.drop_duplicates().reset_index(drop=True)
autism_semantictypes
# Out:
#                    autism_subtype               diseaseSemanticType
# 0        Autism Spectrum Disorder  Mental or Behavioral Dysfunction
# 1                   Rett Syndrome               Disease or Syndrome
# 2              Fragile X Syndrome               Disease or Syndrome
# 3      MECP2 duplication Syndrome               Disease or Syndrome
# 4      Tuberous Sclerosis Complex               Disease or Syndrome
# 5               Angelman Syndrome               Disease or Syndrome
# 6                Timothy Syndrome               Disease or Syndrome
# 7      Smith-Lemli-Opitz Syndrome               Disease or Syndrome
# 8               Neurofibromatosis               Disease or Syndrome
# 9        Hamartoma tumor Syndrome                Neoplastic Process
# 10                  Down Syndrome               Disease or Syndrome
# 11                 Cohen Syndrome            Congenital Abnormality
# 12     Cornelia de Lange Syndrome               Disease or Syndrome
# 13                Charge Syndrome               Disease or Syndrome
# 14                Noonan Syndrome               Disease or Syndrome
# 15               William Syndrome               Disease or Syndrome
# 16              Digeorge Syndrome               Disease or Syndrome
# 17  Macrocephaly/Autism Syndrome                Disease or Syndrome

# %%
autism_new_ids = autism_new_ids.merge(autism_semantictypes, left_on='diseaseName', right_on='autism_subtype', how='inner')
autism_new_ids = autism_new_ids.drop('autism_subtype', axis=1)

# %%
autism_new_ids
# Out:
#                       diseaseName diseaseId  autism_subtype_broad diseaseType  \
# 0        Autism Spectrum Disorder       A00  Non-Syndromic Autism     disease
# 1                   Rett Syndrome       A01      Syndromic Autism     disease
# 2              Fragile X Syndrome       A02      Syndromic Autism     disease
# 3      MECP2 duplication Syndrome       A03      Syndromic Autism     disease
# 4      Tuberous Sclerosis Complex       A04      Syndromic Autism     disease
# 5               Angelman Syndrome       A05      Syndromic Autism     disease
# 6                Timothy Syndrome       A06      Syndromic Autism     disease
# 7      Smith-Lemli-Opitz Syndrome       A07      Syndromic Autism     disease
# 8               Neurofibromatosis       A08      Syndromic Autism     disease
# 9        Hamartoma tumor Syndrome       A09      Syndromic Autism     disease
# 10                  Down Syndrome       A10      Syndromic Autism     disease
# 11                 Cohen Syndrome       A11      Syndromic Autism     disease
# 12     Cornelia de Lange Syndrome       A12      Syndromic Autism     disease
# 13                Charge Syndrome       A13      Syndromic Autism     disease
# 14                Noonan Syndrome       A14      Syndromic Autism     disease
# 15               William Syndrome       A15      Syndromic Autism     disease
# 16              Digeorge Syndrome       A16      Syndromic Autism     disease
# 17  Macrocephaly/Autism Syndrome        A17      Syndromic Autism     disease
#
#                            diseaseClass               diseaseSemanticType
# 0                                   F03  Mental or Behavioral Dysfunction
# 1                               C10;C16               Disease or Syndrome
# 2                           C10;C16;C23               Disease or Syndrome
# 3                               C10;C16               Disease or Syndrome
# 4                   C04;C10;C12;C13;C16               Disease or Syndrome
# 5                               C10;C16               Disease or Syndrome
# 6                   C05;C14;C16;C23;F03               Disease or Syndrome
# 7                               C16;C18               Disease or Syndrome
# 8               C04;C09;C10;C16;C17;C23               Disease or Syndrome
# 9                               C04;C16                Neoplastic Process
# 10  C04;C09;C10;C11;C15;C16;C23;F01;F03               Disease or Syndrome
# 11      C05;C10;C11;C16;C18;C23;F01;F03            Congenital Abnormality
# 12                              C10;C16               Disease or Syndrome
# 13                                  C16               Disease or Syndrome
# 14          C04;C05;C10;C14;C16;C17;C23               Disease or Syndrome
# 15                          C10;C14;C16               Disease or Syndrome
# 16              C05;C14;C15;C16;C19;C23               Disease or Syndrome
# 17                  C05;C10;C16;C23;F03               Disease or Syndrome

# %% [markdown]
# ## Group autisms in raw data

# %%
autism_new_ids.head(1)
# Out:
#                 diseaseName diseaseId  autism_subtype_broad diseaseType  \
# 0  Autism Spectrum Disorder       A00  Non-Syndromic Autism     disease
#
#   diseaseClass               diseaseSemanticType
# 0          F03  Mental or Behavioral Dysfunction

# %%
old_autism_keys = autisms[['diseaseId', 'autism_subtype']]
old_autism_keys = old_autism_keys.rename(columns={'diseaseId': 'diseaseId_old', 'autism_subtype': 'diseaseName'})

autism_new_ids = autism_new_ids.merge(old_autism_keys, on='diseaseName', how='left')

# %%
autism_new_ids.head(1)
# Out:
#                 diseaseName diseaseId  autism_subtype_broad diseaseType  \
# 0  Autism Spectrum Disorder       A00  Non-Syndromic Autism     disease
#
#   diseaseClass               diseaseSemanticType diseaseId_old
# 0          F03  Mental or Behavioral Dysfunction      C0004352

# %%
autism_new_ids = autism_new_ids.rename(columns={
    'diseaseName': 'new_diseaseName',
    'diseaseId': 'new_diseaseId',
    'diseaseType': 'new_diseaseType',
    'diseaseClass': 'new_diseaseClass',
    'diseaseSemanticType': 'new_diseaseSemanticType',
    'diseaseId_old': 'diseaseId'
})

# %%
merged_df = df.merge(autism_new_ids, on='diseaseId',how='left')
merged_df.head(1)
# Out:
#    geneId geneSymbol    DSI    DPI diseaseId   diseaseName diseaseType  \
# 0       1       A1BG  0.857  0.172  C0019209  Hepatomegaly   phenotype
#
#   diseaseClass diseaseSemanticType  score  ...  YearFinal  NofPmids  NofSnps  \
# 0      C06;C23             Finding    0.3  ...     2017.0         1        0
#
#       source  new_diseaseName new_diseaseId autism_subtype_broad  \
# 0  CTD_human              NaN           NaN                  NaN
#
#   new_diseaseType new_diseaseClass new_diseaseSemanticType
# 0             NaN              NaN                     NaN
#
# [1 rows x 22 columns]

# %%
merged_df['diseaseId'] = merged_df['new_diseaseId'].combine_first(merged_df['diseaseId'])
merged_df['diseaseName'] = merged_df['new_diseaseName'].combine_first(merged_df['diseaseName'])
merged_df['diseaseType'] = merged_df['new_diseaseType'].combine_first(merged_df['diseaseType'])
merged_df['diseaseClass'] = merged_df['new_diseaseClass'].combine_first(merged_df['diseaseClass'])
merged_df['diseaseSemanticType'] = merged_df['new_diseaseSemanticType'].combine_first(merged_df['diseaseSemanticType'])
merged_df.head()
# Out:
#    geneId geneSymbol    DSI    DPI diseaseId               diseaseName  \
# 0       1       A1BG  0.857  0.172  C0019209              Hepatomegaly
# 1       1       A1BG  0.857  0.172  C0036341             Schizophrenia
# 2       2        A2M  0.564  0.724  C0002395       Alzheimer's Disease
# 3       2        A2M  0.564  0.724  C0007102  Malignant tumor of colon
# 4       2        A2M  0.564  0.724  C0009375         Colonic Neoplasms
#
#   diseaseType diseaseClass               diseaseSemanticType  score  ...  \
# 0   phenotype      C06;C23                           Finding    0.3  ...
# 1     disease          F03  Mental or Behavioral Dysfunction    0.3  ...
# 2     disease      C10;F03               Disease or Syndrome    0.4  ...
# 3     disease      C04;C06                Neoplastic Process    0.3  ...
# 4       group      C04;C06                Neoplastic Process    0.3  ...
#
#    YearFinal  NofPmids  NofSnps     source  new_diseaseName new_diseaseId  \
# 0     2017.0         1        0  CTD_human              NaN           NaN
# 1     2015.0         1        0  CTD_human              NaN           NaN
# 2     2016.0         3        0  CTD_human              NaN           NaN
# 3     2004.0         1        0  CTD_human              NaN           NaN
# 4     2004.0         1        0  CTD_human              NaN           NaN
#
#   autism_subtype_broad new_diseaseType new_diseaseClass  \
# 0                  NaN             NaN              NaN
# 1                  NaN             NaN              NaN
# 2                  NaN             NaN              NaN
# 3                  NaN             NaN              NaN
# 4                  NaN             NaN              NaN
#
#   new_diseaseSemanticType
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4                     NaN
#
# [5 rows x 22 columns]

# %%
merged_df['autism_subtype_broad'] = merged_df['autism_subtype_broad'].fillna('Not Autism')

# %%
grouped_df = merged_df.drop([
    'new_diseaseName',
    'new_diseaseId',
    'new_diseaseType',
    'new_diseaseClass',
    'new_diseaseSemanticType'
    ], axis=1)

# %%
grouped_df.head()
# Out:
#    geneId geneSymbol    DSI    DPI diseaseId               diseaseName  \
# 0       1       A1BG  0.857  0.172  C0019209              Hepatomegaly
# 1       1       A1BG  0.857  0.172  C0036341             Schizophrenia
# 2       2        A2M  0.564  0.724  C0002395       Alzheimer's Disease
# 3       2        A2M  0.564  0.724  C0007102  Malignant tumor of colon
# 4       2        A2M  0.564  0.724  C0009375         Colonic Neoplasms
#
#   diseaseType diseaseClass               diseaseSemanticType  score        EI  \
# 0   phenotype      C06;C23                           Finding    0.3       NaN
# 1     disease          F03  Mental or Behavioral Dysfunction    0.3       NaN
# 2     disease      C10;F03               Disease or Syndrome    0.4  0.848485
# 3     disease      C04;C06                Neoplastic Process    0.3       NaN
# 4       group      C04;C06                Neoplastic Process    0.3       NaN
#
#    YearInitial  YearFinal  NofPmids  NofSnps     source autism_subtype_broad
# 0       2017.0     2017.0         1        0  CTD_human           Not Autism
# 1       2015.0     2015.0         1        0  CTD_human           Not Autism
# 2       1998.0     2016.0         3        0  CTD_human           Not Autism
# 3       2004.0     2004.0         1        0  CTD_human           Not Autism
# 4       2004.0     2004.0         1        0  CTD_human           Not Autism

# %%
grouped_df['autism_subtype_broad'].unique()
# Out:
# array(['Not Autism', 'Non-Syndromic Autism', 'Syndromic Autism'],
#       dtype=object)

# %% [markdown]
# # Export data

# %%
grouped_df.to_csv('processed_data/curated_gene_disease_associations_autism_grouped.csv', sep='\t')
