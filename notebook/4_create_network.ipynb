# %%
import pandas as pd
import numpy as np
import networkx as nx
import nxviz as nv
from nxviz import MatrixPlot, ArcPlot, CircosPlot
import matplotlib.pyplot as plt

# %% [markdown]
# # Import data and delete nodes and edges

# %%
nodes = pd.read_csv("processed_data/nodes_diseases_AutismGrouped.csv")
nodes.head(2)
# Out:
#   diseaseId    diseaseName diseaseType diseaseClass  \
# 0  C0019209   Hepatomegaly   phenotype      C06;C23
# 1  C0036341  Schizophrenia     disease          F03
#
#                 diseaseSemanticType autism_subtype_broad  n_genes  is_autism
# 0                           Finding           Not Autism       43      False
# 1  Mental or Behavioral Dysfunction           Not Autism     1022      False

# %%
edges = pd.read_csv("processed_data/edges_shared_genes_AutismGrouped.csv")
edges.head(2)
# Out:
#   diseaseId_x diseaseId_y  n_shared_genes  n_genes_x  n_genes_y  \
# 0         A00         A01               3        292          9
# 1         A00         A02               1        292          3
#
#    n_total_genes         p     p_log
# 0           9413  0.002154  2.666773
# 1           9413  0.090187  1.044855

# %% [markdown]
# ## Delete edges with p > 0.001

# %%
edges_p3 = edges[edges['p_log']>=3]
edges_p3.head()
# Out:
#    diseaseId_x diseaseId_y  n_shared_genes  n_genes_x  n_genes_y  \
# 3          A00         A04               3        292          4
# 9          A00         A10               5        292         23
# 23         A00    C0001430               8        292         36
# 27         A00    C0001723               4        292          6
# 33         A00    C0001956               9        292         47
#
#     n_total_genes         p     p_log
# 3            9413  0.000115  3.937982
# 9            9413  0.000583  3.234176
# 23           9413  0.000011  4.968263
# 27           9413  0.000013  4.888589
# 33           9413  0.000011  4.961774

# %% [markdown]
# # Load data into NetworkX graph (p<0.01)

# %%
# Create the NetworkX graph
G = nx.Graph()

# Add nodes
for idx, row in nodes.iterrows():
    G.add_node(row['diseaseId'], 
               diseaseName=row['diseaseName'],
               diseaseType=row['diseaseType'],
               diseaseClass=row['diseaseClass'],
               diseaseSemanticType=row['diseaseSemanticType'],
               autism_subtype_broad=row['autism_subtype_broad'],
               n_genes=row['n_genes'],
               is_autism=row['is_autism'])

# Add edges
for idx, row in edges_p3.iterrows():
    G.add_edge(row['diseaseId_x'], row['diseaseId_y'], 
               n_shared_genes=row['n_shared_genes'],
               n_genes_x=row['n_genes_x'],
               n_genes_y=row['n_genes_y'],
               n_total_genes=row['n_total_genes'],
               p=row['p'],
               p_log=row['p_log'])

# %% [markdown]
# # Degree & Betweenness Centrality

# %% [markdown]
# ## Degree & Degree centrality

# %%
deg_cent = nx.degree_centrality(G)

for n, d in G.nodes(data=True):
    d['degree'] = nx.degree(G, n)
    d['degree_centrality'] = deg_cent[n]

# %% [markdown]
# ## Betweenness centrality

# %%
btw_cent = nx.betweenness_centrality(G)

for n, d in G.nodes(data=True):
    d['btw_centrality'] = btw_cent[n]

# %% [markdown]
# ## Save network containing all diseases

# %%
nx.write_graphml_lxml(G, "graphml/p3_network_all_diseases.graphml")

# %% [markdown]
# ## Create network only with autism and their neighbors

# %%
autism_nodes = [n for n, d in G.nodes(data=True) if d['is_autism']==True]
autism_subgraph_nodes = set(autism_nodes)
for node in autism_nodes:
    autism_subgraph_nodes = autism_subgraph_nodes.union(set(G.neighbors(node)))

autism_subgraph_nodes
# Out:
# {'A00',
#  'A01',
#  'A02',
#  'A03',
#  'A04',
#  'A05',
#  'A06',
#  'A07',
#  'A08',
#  'A09',
#  'A10',
#  'A11',
#  'A12',
#  'A13',
#  'A14',
#  'A15',
#  'A16',
#  'A17',
#  'C0000772',
#  'C0001430',
#  'C0001723',
#  'C0001956',
#  'C0001969',
#  'C0001973',
#  'C0002152',
#  'C0002395',
#  'C0002888',
#  'C0003081',
#  'C0003090',
#  'C0003469',
#  'C0003615',
#  'C0003811',
#  'C0003865',
#  'C0003869',
#  'C0003873',
#  'C0003875',
#  'C0004096',
#  'C0004114',
#  'C0004153',
#  'C0004930',
#  'C0004936',
#  'C0005586',
#  'C0005587',
#  'C0005684',
#  'C0005695',
#  'C0005944',
#  'C0006111',
#  'C0006272',
#  'C0006434',
#  'C0006826',
#  'C0007097',
#  'C0007102',
#  'C0007103',
#  'C0007112',
#  'C0007115',
#  'C0007131',
#  'C0007134',
#  'C0007137',
#  'C0007194',
#  'C0007279',
#  'C0007370',
#  'C0007786',
#  'C0007847',
#  'C0007959',
#  'C0008073',
#  'C0008149',
#  'C0008297',
#  'C0008909',
#  'C0009171',
#  'C0009241',
#  'C0009319',
#  'C0009375',
#  'C0009402',
#  'C0009404',
#  'C0009405',
#  'C0010273',
#  'C0010346',
#  'C0010474',
#  'C0010709',
#  'C0010828',
#  'C0011206',
#  'C0011265',
#  'C0011570',
#  'C0011573',
#  'C0011574',
#  'C0011581',
#  'C0011615',
#  'C0011757',
#  'C0011848',
#  'C0011853',
#  'C0013182',
#  'C0013221',
#  'C0013295',
#  'C0013386',
#  'C0013390',
#  'C0013403',
#  'C0013415',
#  'C0013604',
#  'C0013720',
#  'C0014170',
#  'C0014324',
#  'C0014544',
#  'C0014549',
#  'C0015423',
#  'C0015625',
#  'C0015923',
#  'C0015967',
#  'C0016722',
#  'C0017185',
#  'C0017636',
#  'C0017638',
#  'C0017658',
#  'C0017671',
#  'C0018051',
#  'C0018133',
#  'C0018671',
#  'C0018798',
#  'C0018801',
#  'C0018802',
#  'C0018916',
#  'C0019147',
#  'C0019151',
#  'C0019158',
#  'C0019337',
#  'C0020255',
#  'C0020305',
#  'C0020429',
#  'C0020452',
#  'C0020507',
#  'C0020514',
#  'C0020538',
#  'C0020594',
#  'C0020625',
#  'C0020649',
#  'C0020796',
#  'C0021361',
#  'C0021368',
#  'C0021712',
#  'C0022333',
#  'C0022658',
#  'C0022660',
#  'C0022665',
#  'C0023012',
#  'C0023014',
#  'C0023212',
#  'C0023241',
#  'C0023290',
#  'C0023418',
#  'C0023443',
#  'C0023452',
#  'C0023453',
#  'C0023466',
#  'C0023467',
#  'C0023470',
#  'C0023480',
#  'C0023518',
#  'C0023798',
#  'C0023801',
#  'C0024121',
#  'C0024299',
#  'C0024507',
#  'C0024586',
#  'C0024713',
#  'C0025193',
#  'C0025202',
#  'C0025261',
#  'C0025286',
#  'C0025312',
#  'C0025363',
#  'C0025568',
#  'C0025958',
#  'C0026613',
#  'C0026640',
#  'C0026764',
#  'C0026825',
#  'C0026827',
#  'C0026998',
#  'C0027019',
#  'C0027066',
#  'C0027540',
#  'C0027626',
#  'C0027627',
#  'C0027659',
#  'C0027746',
#  'C0027765',
#  'C0027809',
#  'C0027819',
#  'C0028754',
#  'C0028756',
#  'C0028768',
#  'C0029261',
#  'C0029434',
#  'C0029453',
#  'C0029463',
#  'C0029925',
#  'C0030193',
#  'C0030214',
#  'C0030421',
#  'C0030422',
#  'C0030567',
#  'C0030849',
#  'C0031511',
#  'C0032230',
#  'C0032617',
#  'C0033578',
#  'C0033922',
#  'C0033953',
#  'C0033958',
#  'C0033975',
#  'C0034069',
#  'C0034189',
#  'C0034642',
#  'C0035126',
#  'C0035234',
#  'C0035508',
#  'C0036118',
#  'C0036337',
#  'C0036341',
#  'C0036349',
#  'C0036358',
#  'C0036572',
#  'C0036690',
#  'C0036875',
#  'C0036902',
#  'C0036996',
#  'C0037769',
#  'C0037928',
#  'C0038220',
#  'C0038279',
#  'C0038358',
#  'C0038433',
#  'C0038450',
#  'C0038587',
#  'C0039590',
#  'C0040034',
#  'C0040136',
#  'C0040954',
#  'C0041409',
#  'C0041671',
#  'C0041696',
#  'C0041755',
#  'C0042029',
#  'C0042484',
#  'C0043144',
#  'C0079731',
#  'C0079745',
#  'C0079758',
#  'C0079765',
#  'C0085129',
#  'C0085159',
#  'C0085220',
#  'C0085261',
#  'C0085584',
#  'C0085593',
#  'C0085742',
#  'C0085762',
#  'C0085786',
#  'C0085996',
#  'C0085997',
#  'C0086132',
#  'C0086133',
#  'C0086189',
#  'C0086196',
#  'C0086237',
#  'C0086664',
#  'C0087169',
#  'C0149958',
#  'C0151468',
#  'C0151526',
#  'C0151603',
#  'C0151779',
#  'C0151857',
#  'C0152013',
#  'C0152427',
#  'C0153381',
#  'C0153594',
#  'C0153601',
#  'C0153633',
#  'C0153943',
#  'C0154040',
#  'C0154045',
#  'C0154060',
#  'C0156147',
#  'C0158995',
#  'C0175693',
#  'C0175704',
#  'C0178417',
#  'C0178824',
#  'C0205646',
#  'C0205647',
#  'C0205648',
#  'C0205649',
#  'C0205650',
#  'C0205651',
#  'C0205696',
#  'C0205697',
#  'C0205698',
#  'C0205699',
#  'C0205768',
#  'C0205788',
#  'C0205789',
#  'C0205822',
#  'C0205823',
#  'C0205834',
#  'C0206682',
#  'C0206695',
#  'C0206698',
#  'C0206739',
#  'C0220704',
#  'C0221263',
#  'C0233477',
#  'C0233612',
#  'C0233794',
#  'C0234230',
#  'C0234238',
#  'C0234254',
#  'C0234533',
#  'C0234535',
#  'C0234985',
#  'C0235527',
#  'C0236018',
#  'C0236663',
#  'C0236733',
#  'C0236736',
#  'C0236804',
#  'C0236807',
#  'C0238111',
#  'C0238198',
#  'C0238463',
#  'C0241210',
#  'C0241910',
#  'C0242379',
#  'C0243026',
#  'C0259783',
#  'C0259785',
#  'C0265210',
#  'C0265275',
#  'C0265325',
#  'C0265326',
#  'C0265329',
#  'C0267380',
#  'C0270496',
#  'C0270611',
#  'C0270612',
#  'C0270823',
#  'C0270824',
#  'C0270844',
#  'C0270846',
#  'C0272945',
#  'C0276496',
#  'C0278996',
#  'C0279607',
#  'C0279702',
#  'C0280100',
#  'C0280141',
#  'C0280302',
#  'C0280313',
#  'C0280321',
#  'C0280324',
#  'C0280783',
#  'C0280785',
#  'C0281784',
#  'C0282126',
#  'C0282193',
#  'C0302592',
#  'C0311335',
#  'C0333233',
#  'C0333463',
#  'C0334082',
#  'C0334579',
#  'C0334580',
#  'C0334581',
#  'C0334582',
#  'C0334583',
#  'C0334605',
#  'C0334606',
#  'C0334607',
#  'C0334608',
#  'C0334609',
#  'C0334610',
#  'C0334611',
#  'C0338070',
#  'C0338582',
#  'C0338656',
#  'C0338715',
#  'C0338831',
#  'C0338908',
#  'C0341823',
#  'C0341869',
#  'C0342384',
#  'C0343114',
#  'C0343528',
#  'C0344315',
#  'C0344456',
#  'C0345893',
#  'C0345905',
#  'C0346099',
#  'C0346153',
#  'C0346191',
#  'C0347515',
#  'C0349231',
#  'C0349535',
#  'C0349604',
#  'C0349639',
#  'C0349680',
#  'C0362030',
#  'C0376280',
#  'C0376338',
#  'C0376358',
#  'C0376545',
#  'C0376634',
#  'C0391826',
#  'C0393698',
#  'C0393699',
#  'C0393706',
#  'C0393734',
#  'C0400966',
#  'C0422850',
#  'C0422852',
#  'C0422853',
#  'C0422854',
#  'C0422855',
#  'C0424295',
#  'C0427201',
#  'C0427202',
#  'C0431121',
#  'C0431350',
#  'C0431406',
#  'C0432197',
#  'C0432235',
#  'C0432417',
#  'C0438413',
#  'C0452047',
#  'C0454655',
#  'C0457190',
#  'C0458247',
#  'C0458257',
#  'C0458259',
#  'C0473574',
#  'C0476089',
#  'C0494463',
#  'C0494475',
#  'C0496905',
#  'C0496920',
#  'C0496956',
#  'C0525045',
#  'C0543888',
#  'C0546126',
#  'C0546878',
#  'C0547065',
#  'C0549473',
#  'C0553558',
#  'C0553586',
#  'C0555198',
#  'C0585362',
#  'C0585540',
#  'C0587248',
#  'C0596263',
#  'C0600427',
#  'C0600467',
#  'C0677608',
#  'C0677776',
#  'C0678202',
#  'C0678222',
#  'C0679465',
#  'C0684249',
#  'C0684276',
#  'C0699790',
#  'C0699791',
#  'C0740457',
#  'C0750900',
#  'C0750901',
#  'C0750935',
#  'C0750936',
#  'C0751056',
#  'C0751081',
#  'C0751088',
#  'C0751110',
#  'C0751111',
#  'C0751117',
#  'C0751118',
#  'C0751119',
#  'C0751123',
#  'C0751156',
#  'C0751157',
#  'C0751197',
#  'C0751198',
#  'C0751211',
#  'C0751212',
#  'C0751213',
#  'C0751214',
#  'C0751217',
#  'C0751257',
#  'C0751292',
#  'C0751293',
#  'C0751294',
#  'C0751295',
#  'C0751303',
#  'C0751304',
#  'C0751316',
#  'C0751330',
#  'C0751348',
#  'C0751349',
#  'C0751350',
#  'C0751351',
#  'C0751352',
#  'C0751353',
#  'C0751354',
#  'C0751355',
#  'C0751407',
#  'C0751408',
#  'C0751456',
#  'C0751494',
#  'C0751495',
#  'C0751496',
#  'C0751508',
#  'C0751509',
#  'C0751510',
#  'C0751511',
#  'C0751522',
#  'C0751523',
#  'C0751524',
#  'C0751674',
#  'C0795907',
#  'C0796222',
#  'C0851140',
#  'C0851578',
#  'C0854119',
#  'C0856823',
#  'C0858252',
#  'C0878682',
#  'C0917730',
#  'C0917798',
#  'C0917816',
#  'C0919267',
#  'C0949272',
#  'C0949331',
#  'C0971858',
#  'C0993582',
#  'C1112155',
#  'C1136249',
#  'C1140680',
#  'C1153706',
#  'C1168401',
#  'C1257877',
#  'C1257931',
#  'C1261473',
#  'C1262477',
#  'C1263846',
#  'C1266042',
#  'C1266043',
#  'C1266044',
#  'C1266181',
#  'C1269683',
#  'C1270972',
#  'C1275081',
#  'C1279420',
#  'C1292775',
#  'C1306837',
#  'C1319315',
#  'C1321489',
#  'C1321905',
#  'C1328252',
#  'C1333990',
#  'C1333991',
#  'C1334261',
#  'C1334271',
#  'C1335107',
#  'C1335929',
#  'C1384406',
#  'C1384408',
#  'C1384600',
#  'C1384666',
#  'C1450010',
#  'C1458155',
#  'C1527197',
#  'C1527249',
#  'C1527306',
#  'C1527366',
#  'C1527404',
#  'C1535926',
#  'C1541844',
#  'C1542327',
#  'C1563937',
#  'C1565662',
#  'C1565950',
#  'C1565951',
#  'C1571983',
#  'C1571984',
#  'C1691228',
#  'C1692886',
#  'C1704230',
#  'C1704377',
#  'C1719672',
#  'C1720811',
#  'C1802395',
#  'C1834711',
#  'C1834712',
#  'C1835047',
#  'C1838604',
#  'C1839333',
#  'C1842036',
#  'C1843247',
#  'C1846058',
#  'C1846385',
#  'C1846386',
#  'C1846388',
#  'C1846389',
#  'C1847319',
#  'C1848211',
#  'C1848599',
#  'C1849437',
#  'C1852406',
#  'C1854336',
#  'C1854630',
#  'C1855008',
#  'C1858854',
#  'C1861028',
#  'C1861848',
#  'C1861906',
#  'C1863052',
#  'C1863053',
#  'C1863391',
#  'C1865070',
#  'C1865285',
#  'C1866398',
#  'C1867610',
#  'C1868148',
#  'C1868633',
#  'C1879321',
#  'C1955869',
#  'C1956130',
#  'C1956131',
#  'C1956132',
#  'C1959583',
#  'C1959588',
#  'C1961102',
#  'C1961112',
#  'C1968550',
#  'C1968551',
#  'C1968552',
#  'C1968782',
#  'C2267233',
#  'C2350875',
#  'C2350876',
#  'C2350988',
#  'C2609414',
#  'C2674723',
#  'C2675336',
#  'C2676500',
#  'C2677087',
#  'C2677326',
#  'C2678248',
#  'C2678478',
#  'C2713347',
#  'C2713368',
#  'C2750460',
#  'C2750805',
#  'C2751494',
#  'C2751536',
#  'C2751642',
#  'C2752042',
#  'C2931082',
#  'C2931367',
#  'C2931456',
#  'C2931672',
#  'C2931713',
#  'C2931817',
#  'C2931822',
#  'C2936349',
#  'C2936719',
#  'C3149711',
#  'C3149841',
#  'C3150705',
#  'C3151355',
#  'C3151356',
#  'C3160814',
#  'C3163622',
#  'C3179349',
#  'C3179502',
#  'C3241937',
#  'C3266101',
#  'C3275521',
#  'C3281247',
#  'C3463824',
#  'C3489413',
#  'C3494181',
#  'C3495874',
#  'C3549448',
#  'C3552552',
#  'C3552553',
#  'C3554518',
#  'C3554519',
#  'C3683846',
#  'C3711376',
#  'C3713418',
#  'C3714043',
#  'C3714756',
#  'C3714976',
#  'C3805278',
#  'C3810406',
#  'C3854181',
#  'C3887461',
#  'C3888307',
#  'C3888308',
#  'C3888309',
#  'C3891815',
#  'C4011754',
#  'C4025414',
#  'C4042891',
#  'C4046029',
#  'C4048158',
#  'C4225179',
#  'C4225426',
#  'C4277690',
#  'C4302111',
#  'C4305240',
#  'C4310712',
#  'C4316791',
#  'C4316903',
#  'C4317109',
#  'C4317123',
#  'C4478700',
#  'C4478701',
#  'C4479708',
#  'C4479709',
#  'C4505390',
#  'C4505436'}

# %%
G_autism = G.subgraph(autism_subgraph_nodes).copy()

# %%
deg_cent = nx.degree_centrality(G_autism)

for n, d in G_autism.nodes(data=True):
    d['degree_autismonly'] = nx.degree(G_autism, n)
    d['degree_centrality_autismonly'] = deg_cent[n]

# %%
btw_cent_autism = nx.betweenness_centrality(G_autism)

for n, d in G_autism.nodes(data=True):
    d['btw_centrality_autismonly'] = btw_cent_autism[n]

# %%
p_logs = [d['p_log'] for n1, n2, d in G_autism.edges(data=True)]

# %%
for n1, n2, d in G_autism.edges(data=True):
    if d['p_log'] >= 10:
        d['p_log_trunc'] = 10
    else:
        d['p_log_trunc'] = int(d['p_log'])

# %% [markdown]
# ### Save network only with autism and their neighbors

# %%
nx.write_graphml_lxml(G_autism, "graphml/p3_network_autism_neighbors.graphml")
